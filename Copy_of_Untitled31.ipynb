# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthikjv27/my-first-project/blob/main/Copy_of_Untitled31.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("/content/Heart_Disease_Prediction.csv")

# %%
df
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
# ...

# %% [markdown]
# Data Preprocessing (Changing the datatype of the inputs and outputs which the algorithm can understand)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df["Heart Disease"]=le.fit_transform(df["Heart Disease"])

# %%
df["Heart Disease"]
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 265    0
# 266    0
# 267    0
# 268    0
# 269    1
# Name: Heart Disease, Length: 270, dtype: int64

# %% [markdown]
# Input and Output Declaration

# %%
inp=df.drop(columns=["Heart Disease"])
output=df["Heart Disease"]

# %%
inp
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
# ...

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 265    0
# 266    0
# 267    0
# 268    0
# 269    1
# Name: Heart Disease, Length: 270, dtype: int64

# %% [markdown]
# Data Spliting

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(inp,output,test_size=0.2,random_state=12)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (216, 13)
# (54, 13)
# (216,)
# (54,)

# %% [markdown]
# Model Training

# %%
from sklearn.naive_bayes import GaussianNB

# %%
NB=GaussianNB()

# %%
NB.fit(x_train,y_train)
# Out:
# GaussianNB()

# %% [markdown]
# Model Evalution

# %%
y_predict=NB.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
test=accuracy_score(y_test,y_predict)

# %%
test
# Out:
# 0.7407407407407407

# %% [markdown]
# Model Prediction

# %%
check=NB.predict([[23,0,23,212,23,34,12,0.5,34,32,10,89,4.5]])
check
# Out:
# array([1])
